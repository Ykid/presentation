# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

def split_eng_sentences(series:pd.Series) -> pd.Series:
        lowered = "|".join(series).lower()
        return pd.Series(tokenizer.tokenize(lowered))

def generate_word_cloud_plot(word_series: pd.Series, stop_words):
    # Create and generate a word cloud image:
    text = " ".join(word_series)
    print ("There are {} words in the input series.".format(len(text)))
    wordcloud = WordCloud(stopwords=stop_words, background_color="white", collocations=False).generate(text)
    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

print('set up completed')
# Out:
# set up completed

# %% [markdown]
# set up stopwords, these are the words to be ignored

# %%
eng_stopwords = set(STOPWORDS)
eng_stopwords.update({'goodnotes', 'goodnote', 'note', 'notes', 'app'})

def generate_title_and_review_plot(path: str, stop_words):
    reviews = pd.read_csv(path)
    title_series = split_eng_sentences(reviews.title)
    review_series = split_eng_sentences(reviews.review)
    generate_word_cloud_plot(title_series, stop_words)
    generate_word_cloud_plot(review_series, stop_words)

# %% [markdown]
# What is the most frequent word in the title of review in US ?

# %%
us_path = "./reviews/United_States/reviews_United_States_2019_10_27.csv"
generate_title_and_review_plot(us_path, eng_stopwords)
# Out:
# There are 12111 words in the input series.
# There are 156913 words in the input series.

# %% [markdown]
# What is the most frequent word in the title of review in HK ?

# %%
hk_path = "./reviews/HongKong/reviews_HongKong_2019_10_27.csv"
generate_title_and_review_plot(hk_path, eng_stopwords)
# Out:
# There are 5825 words in the input series.
# There are 44779 words in the input series.

# %% [markdown]
# What is the most frequent word in the title of review in India ?

# %%
india_path = "./reviews/India/reviews_India_2019_10_27.csv"
generate_title_and_review_plot(india_path, eng_stopwords)
# Out:
# There are 8180 words in the input series.
# There are 67500 words in the input series.

# %% [markdown]
# What is the most frequent word in the title of review in Philippines ?

# %%
india_path = "./reviews/Philippines/reviews_Philippines_2019_10_27.csv"
generate_title_and_review_plot(india_path, eng_stopwords)
# Out:
# There are 3123 words in the input series.
# There are 34084 words in the input series.

# %% [markdown]
# What is the most frequent word in the title of review in Australia ?

# %%
aus_path = "./reviews/Australia/reviews_Australia_2019_10_27.csv"
generate_title_and_review_plot(aus_path, eng_stopwords)
# Out:
# There are 6494 words in the input series.
# There are 83424 words in the input series.

# %% [markdown]
# What is the most frequent word in the title of review in Canada ?

# %%
ca_path = "./reviews/Canada/reviews_Canada_2019_10_27.csv"
generate_title_and_review_plot(ca_path, eng_stopwords)
# Out:
# There are 11462 words in the input series.
# There are 143620 words in the input series.
